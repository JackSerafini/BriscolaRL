# %%
# %load_ext autoreload
# %autoreload 2

# %%
from briscola import Briscola

# %%
environment = Briscola()
environment.reset()

# %%
len(environment.deck)

# %%
environment.player_hand

# %%
environment.step(0)
