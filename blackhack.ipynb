# %%
import gymnasium as gym

# %%
class Briscola(gym.Env):
    def __init__(self):
        """
        There are 4 suits, each ranging from 1 to 13
        """
        
        pass

    def reset(self):
        pass

    def step(self):
        pass
